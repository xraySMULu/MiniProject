# %%
import pandas as pd
import pipeline_utilities as p_utils

# %% [markdown]
# Import the Data

# %%
china_df = pd.read_csv("Resources/beijing-pm2-5.csv")
china_df.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %% [markdown]
# Train the Model

# %%
# Train a model for the fareast using the china_model_generator function
fareast_model = p_utils.china_model_generator(china_df)
china_ne_df = pd.read_csv("Resources/beijing-pm2-5-NE.csv")
china_nw_df = pd.read_csv("Resources/beijing-pm2-5-NW.csv")
china_se_df = pd.read_csv("Resources/beijing-pm2-5-SE.csv")
china_cv_df = pd.read_csv("Resources/beijing-pm2-5-cv.csv")

fareast_model = p_utils.china_model_generator(china_ne_df)
fareast_model = p_utils.china_model_generator(china_nw_df)
fareast_model = p_utils.china_model_generator(china_se_df)
fareast_model = p_utils.china_model_generator(china_cv_df)
# Out:
# Testing dropped NAs
# ----------
# Mean Squared Error: 6194.036785626118
# R-squared: 0.24002388143762732
# Adjusted R-squared: 0.23919049814029125
# ----------
# Testing no dropped data
# Mean Squared Error: 6304.982036580162
# R-squared: 0.2428093572075951
# Adjusted R-squared: 0.24197902843911223
# ----------
# Returning no dropped data pipeline
# ----------
# Testing dropped NAs
# ----------
# Mean Squared Error: 6001.31533764249
# R-squared: 0.3022158438722843
# Adjusted R-squared: 0.29544671705455383
# ----------
# Testing no dropped data
# Mean Squared Error: 5746.607900010789
# R-squared: 0.31636570358265925
# Adjusted R-squared: 0.30973384298685647
# ----------
# Returning no dropped data pipeline
# ----------
# Testing dropped NAs
# ----------
# Mean Squared Error: 5068.861591525314
# R-squared: 0.30031323483110495
# Adjusted R-squared: 0.2979313224390405
# ----------
# Testing no dropped data
# Mean Squared Error: 5453.299428117112
# R-squared: 0.288673384231823
# ...

# %%
fareast_model
# Out:
# Pipeline(steps=[('One hot encode', OneHotEncoder(handle_unknown='ignore')),
#                 ('Scale', StandardScaler(with_mean=False)),
#                 ('Linear Regression', LinearRegression())])
