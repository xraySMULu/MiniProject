# %%
import pandas as pd
import pipeline_utilities as p_utils

# %% [markdown]
# Import the Data

# %%
china_df = pd.read_csv("Resources/beijing-pm2-5.csv")
china_df.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %% [markdown]
# Train the Model

# %%
# Train a model for the fareast using the china_model_generator function
china_df = china_df.dropna()
fareast_model = p_utils.china_model_generator(china_df, "Beijing")
china_ne_df = pd.read_csv("Resources/beijing-pm2-5-NE.csv")
china_ne_df = china_ne_df.dropna()
china_nw_df = pd.read_csv("Resources/beijing-pm2-5-NW.csv")
china_nw_df = china_nw_df.dropna()
china_se_df = pd.read_csv("Resources/beijing-pm2-5-SE.csv")
china_se_df = china_se_df.dropna()
china_cv_df = pd.read_csv("Resources/beijing-pm2-5-cv.csv")
china_cv_df = china_cv_df.dropna()

fareast_model = p_utils.china_model_generator(china_ne_df, "NE Winds - Beijing")
fareast_model = p_utils.china_model_generator(china_nw_df, "NW Winds - Beijing")
fareast_model = p_utils.china_model_generator(china_se_df, "SE Winds - Beijing")
fareast_model = p_utils.china_model_generator(china_cv_df, "CV Winds - Beijing")
# Out:
# ----------
# * Beijing *
# ----------
# ** Testing dropped NAs
# --> Mean Squared Error: 6431.140054177553
# --> R-squared: 0.25092973797629214
# --> Adjusted R-squared: 0.24985183564222124
# ** Testing no dropped data
# --> Mean Squared Error: 6440.165618117665
# --> R-squared: 0.2472874889253146
# --> Adjusted R-squared: 0.24642122344791018
# ** Returning dropped NAs pipeline
# ----------
# * NE Winds - Beijing *
# ----------
# ** Testing dropped NAs
# --> Mean Squared Error: 6803.653296981884
# --> R-squared: 0.33120420100760306
# --> Adjusted R-squared: 0.32437975407910924
# ** Testing no dropped data
# --> Mean Squared Error: 6981.370973916382
# --> R-squared: 0.3159896638559935
# --> Adjusted R-squared: 0.3090099665484015
# ** Returning dropped NAs pipeline
# ----------
# * NW Winds - Beijing *
# ----------
# ** Testing dropped NAs
# --> Mean Squared Error: 4777.504151623218
# --> R-squared: 0.3271734462073137
# --> Adjusted R-squared: 0.3247690630490313
# ...

# %%
fareast_model
# Out:
# Pipeline(steps=[('One hot encode', OneHotEncoder(handle_unknown='ignore')),
#                 ('Scale', StandardScaler(with_mean=False)),
#                 ('Linear Regression', LinearRegression())])
